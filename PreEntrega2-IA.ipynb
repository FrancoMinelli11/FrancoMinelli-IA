# %%
import openai

# Configuración de la API de OpenAI
openai.api_key = 'xxxx'

# Función para generar código con GPT-4 utilizando el endpoint de chat
def generar_codigo_chat(messages, max_tokens=1000, temperature=0.5):
    response = openai.ChatCompletion.create(
        model="gpt-4",
        messages=messages,
        max_tokens=max_tokens,
        temperature=temperature,
    )
    return response.choices[0].message['content'].strip()

# Función para generar imágenes con DALL-E
def generar_imagen(prompt, n=1, size="1024x1024"):
    response = openai.Image.create(
        prompt=prompt,
        n=n,
        size=size
    )
    return response['data'][0]['url']

# Mensajes para el modelo de chat con few-shot prompting
messages = [
    {"role": "system", "content": "Eres un experto desarrollador, diseñador y optimizador web"},
    {"role": "user", "content": "Escribe un código HTML y CSS para una página web que incluya como mínimo: un título, un encabezado principal y un párrafo de bienvenida."},
    # Ejemplo 1
    {"role": "assistant", "content": """
<!DOCTYPE html>
<html lang="es">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Mi Primer Sitio Web</title>
</head>
<body>
    <h1>Bienvenido</h1>
    <p>Este es mi primer sitio web. Espero que disfrutes la visita.</p>
</body>
</html>
    """},
    #Ejemplo 2
    {"role": "assistant", "content": """ 
    <!DOCTYPE html>
<html lang="es">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Mi Portfolio</title>
    <style>
        /* Estilos globales */
        body {
            font-family: 'Arial', sans-serif;
            margin: 0;
            padding: 0;
            line-height: 1.6;
            background-color: #f4f4f4;
            color: #333;
        }

        /* Contenedor central */
        .container {
            width: 80%;
            margin: 0 auto;
            overflow: hidden;
        }

        /* Estilos del encabezado */
        header {
            background: #333;
            color: #fff;
            padding: 20px 0;
            text-align: center;
        }

        header h1 {
            margin: 0;
            font-size: 2.5em;
        }

        header p {
            font-size: 1.2em;
        }

        /* Barra de navegación */
        nav {
            background: #444;
            color: #fff;
            padding: 10px 0;
            text-align: center;
        }

        nav ul {
            list-style: none;
            padding: 0;
            margin: 0;
        }

        nav ul li {
            display: inline;
            margin: 0 20px;
        }

        nav ul li a {
            color: #fff;
            text-decoration: none;
        }

        nav ul li a:hover {
            color: #f4f4f4;
        }

        /* Sección Sobre Mí */
        section#about {
            padding: 20px 0;
            background: #e2e2e2;
            text-align: center;
        }

        section#about h2 {
            font-size: 2em;
            margin-bottom: 10px;
        }

        /* Sección de Proyectos */
        section#projects {
            padding: 20px 0;
            text-align: center;
        }

        .project-grid {
            display: grid;
            grid-template-columns: repeat(auto-fill, minmax(300px, 1fr));
            gap: 20px;
        }

        .project {
            background: #fff;
            padding: 20px;
            box-shadow: 0 0 10px rgba(0, 0, 0, 0.1);
        }

        .project h3 {
            margin-top: 0;
        }

        .project p {
            margin-bottom: 0;
        }

        /* Pie de página */
        footer {
            background: #333;
            color: #fff;
            padding: 20px 0;
            text-align: center;
        }

        .social-links a {
            color: #fff;
            text-decoration: none;
            margin: 0 10px;
        }

        .social-links a:hover {
            color: #f4f4f4;
        }
    </style>
</head>
<body>
    <header>
        <div class="container">
            <h1>Tu Nombre</h1>
            <p>Desarrollador Web | Diseñador | Freelance</p>
        </div>
    </header>

    <nav>
        <ul>
            <li><a href="#about">Sobre Mí</a></li>
            <li><a href="#projects">Proyectos</a></li>
            <li><a href="#contact">Contacto</a></li>
        </ul>
    </nav>

    <section id="about">
        <div class="container">
            <h2>Sobre Mí</h2>
            <p>Hola, soy un desarrollador web con experiencia en la creación de sitios web y aplicaciones responsivas. Me apasiona el diseño limpio y la codificación eficiente.</p>
        </div>
    </section>

    <section id="projects">
        <div class="container">
            <h2>Proyectos</h2>
            <div class="project-grid">
                <div class="project">
                    <h3>Proyecto 1</h3>
                    <p>Descripción breve del proyecto 1.</p>
                </div>
                <div class="project">
                    <h3>Proyecto 2</h3>
                    <p>Descripción breve del proyecto 2.</p>
                </div>
                <div class="project">
                    <h3>Proyecto 3</h3>
                    <p>Descripción breve del proyecto 3.</p>
                </div>
            </div>
        </div>
    </section>

    <footer>
        <div class="container">
            <p>© 2024 Tu Nombre. Todos los derechos reservados.</p>
            <div class="social-links">
                <a href="#">LinkedIn</a>
                <a href="#">GitHub</a>
                <a href="#">Twitter</a>
            </div>
        </div>
    </footer>
</body>
</html>
 """},
    # Nueva solicitud para el modelo
    {"role": "user", "content": "Escribe un código HTML avanzado y con estilos en CSS para una página web de un portfolio personal."}
]

# Generar código
codigo_generado_chat = generar_codigo_chat(messages)
print("Código HTML generado:")
print(codigo_generado_chat)

# Prompt para DALL-E
prompt_imagen = "Create a modern and minimalist image for the cover of a web developer's personal portfolio. The design should include elements such as a laptop, code on a screen, and a clean and organized work environment. The predominant colors should be soft shades of blue and gray, with black and white details. The image must convey professionalism, creativity and technology. The background should be simple, with enough white space to add text later."

# Generar imagen
url_imagen = generar_imagen(prompt_imagen)
print("URL de la imagen generada:")
print(url_imagen)
# Out:
# Código HTML generado:
# Claro, aquí tienes un ejemplo de un código HTML y CSS para una página de portfolio personal.
#
# ```html
# <!DOCTYPE html>
# <html>
# <head>
#     <title>Portfolio Personal</title>
#     <style>
#         body {
#             font-family: Arial, sans-serif;
#             margin: 0;
#             padding: 0;
#             background-color: #f4f4f4;
#         }
#
#         .header {
#             background-color: #333;
#             color: #fff;
#             padding: 10px;
#             text-align: center;
#         }
#
#         .nav {
#             background-color: #ddd;
#             padding: 10px;
#             text-align: center;
#         }
#
#         .nav a {
#             margin: 0 15px;
#             text-decoration: none;
#             color: black;
#         }
#
#         .content {
#             margin: 15px;
#         }
#
#         .footer {
#             background-color: #333;
#             color: #fff;
#             text-align: center;
# ...
